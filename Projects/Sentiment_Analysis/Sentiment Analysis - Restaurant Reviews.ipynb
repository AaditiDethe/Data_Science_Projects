# %% [markdown]
# # Sentiment Analysis of Restaurant Reviews

# %% [markdown]
# #### Importing essential libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Loading the dataset

# %%
df = pd.read_csv("C:/Data Science/Projects/Sentiment_Analysis/Restaurant_Reviews.tsv", delimiter='\t', quoting=3)

# %%
df.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
df.shape
# Out:
# (1000, 2)

# %%
df.columns
# Out:
# Index(['Review', 'Liked'], dtype='object')

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# #### Importing Essential Libraries for performing NLP on data set

# %%
import nltk
import re
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aadit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# #### Cleaning the reviews

# %%
corpus = []
for i in range(0,1000):
    
    # Cleaning the special charaters from the reviews
    review = re.sub(pattern='[^a-zA-Z]', repl=' ', string = df['Review'][i])
    
    # Converting the entire review into lower case
    review = review.lower()
    
    # Tokenizing the review by words
    review_words = review.split()
    
    # Removing the stop words
    review_words = [word for word in review_words if not word in set(stopwords.words('english'))]
    
    # Stemming the words
    ps = PorterStemmer()
    review = [ps.stem(word) for word in review_words]
    
    # Joining the stemmed words
    review = ' '.join(review)
    
    # Creating a corpus
    corpus.append(review)

# %%
corpus[0:10]
# Out:
# ['wow love place',
#  'crust good',
#  'tasti textur nasti',
#  'stop late may bank holiday rick steve recommend love',
#  'select menu great price',
#  'get angri want damn pho',
#  'honeslti tast fresh',
#  'potato like rubber could tell made ahead time kept warmer',
#  'fri great',
#  'great touch']

# %% [markdown]
# #### Creating the bag of words model

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1500)
X = cv.fit_transform(corpus).toarray()
y = df.iloc[:,1].values

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.02, random_state=0)

# %% [markdown]
# #### Fitting Naive Bayes to the Training set

# %%
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB()
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# #### Predicting the Test set results

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# #### Accuracy, Precision and Recall

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

score1 = accuracy_score(y_test, y_pred)
score2 = precision_score(y_test, y_pred)
score3 = recall_score(y_test, y_pred)

print("----Scores----")
print("Accuracy score is: {}%".format(round(score1*100,2)))
print("Precision score is: {}".format(round(score2,2)))
print("Recall score is: {}".format(round(score3,2)))
# Out:
# ----Scores----
# Accuracy score is: 95.0%
# Precision score is: 0.89
# Recall score is: 1.0

# %% [markdown]
# #### Making the confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[11,  1],
#        [ 0,  8]], dtype=int64)

# %% [markdown]
# #### Plotting the confusion Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize = (10,6))
sns.heatmap(cm, annot=True, cmap="YlGnBu", xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
# Out:
# Text(95.72222222222221, 0.5, 'Actual values')

# %% [markdown]
# #### Hyperparameter tuning the Naive Bayes Classifier

# %%
best_accuracy = 0.0
alpha_val = 0.0
for i in np.arange(0.1,1.1,0.1):
  temp_classifier = MultinomialNB(alpha=i)
  temp_classifier.fit(X_train, y_train)
  temp_y_pred = temp_classifier.predict(X_test)
  score = accuracy_score(y_test, temp_y_pred)
  print("Accuracy score for alpha={} is: {}%".format(round(i,1), round(score*100,2)))
  if score>best_accuracy:
    best_accuracy = score
    alpha_val = i
print('--------------------------------------------')
print('The best accuracy is {}% with alpha value as {}'.format(round(best_accuracy*100, 2), round(alpha_val,1)))
# Out:
# Accuracy score for alpha=0.1 is: 95.0%
# Accuracy score for alpha=0.2 is: 95.0%
# Accuracy score for alpha=0.3 is: 95.0%
# Accuracy score for alpha=0.4 is: 95.0%
# Accuracy score for alpha=0.5 is: 95.0%
# Accuracy score for alpha=0.6 is: 95.0%
# Accuracy score for alpha=0.7 is: 95.0%
# Accuracy score for alpha=0.8 is: 95.0%
# Accuracy score for alpha=0.9 is: 95.0%
# Accuracy score for alpha=1.0 is: 95.0%
# --------------------------------------------
# The best accuracy is 95.0% with alpha value as 0.1

# %%
classifier = MultinomialNB(alpha=0.2)
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=0.2)

# %% [markdown]
# # Predictions

# %%
def predict_sentiment(sample_review):
  sample_review = re.sub(pattern='[^a-zA-Z]',repl=' ', string = sample_review)
  sample_review = sample_review.lower()
  sample_review_words = sample_review.split()
  sample_review_words = [word for word in sample_review_words if not word in set(stopwords.words('english'))]
  ps = PorterStemmer()
  final_review = [ps.stem(word) for word in sample_review_words]
  final_review = ' '.join(final_review)

  temp = cv.transform([final_review]).toarray()
  return classifier.predict(temp)

# %% [markdown]
# #### Predicting values

# %%
sample_review = 'The food is really good here.'

if predict_sentiment(sample_review):
  print('This is a POSITIVE review.')
else:
  print('This is a NEGATIVE review!')
# Out:
# This is a POSITIVE review.

# %%
sample_review = 'The food is really bad here.'

if predict_sentiment(sample_review):
  print('This is a POSITIVE review.')
else:
  print('This is a NEGATIVE review!')
# Out:
# This is a NEGATIVE review!

# %%
sample_review = 'The food is really terribly bad here.'

if predict_sentiment(sample_review):
  print('This is a POSITIVE review.')
else:
  print('This is a NEGATIVE review!')
# Out:
# This is a NEGATIVE review!

# %%
sample_review = 'The food was absolutely wonderful, from preparation to presentation, very pleasing.'

if predict_sentiment(sample_review):
  print('This is a POSITIVE review.')
else:
  print('This is a NEGATIVE review!')
# Out:
# This is a POSITIVE review.

# %%
sample_review = 'The food was absolutely wonderful, from preparation to presentation, very pleasing. But the taste was not much good'

if predict_sentiment(sample_review):
  print('This is a POSITIVE review.')
else:
  print('This is a NEGATIVE review!')
# Out:
# This is a POSITIVE review.
